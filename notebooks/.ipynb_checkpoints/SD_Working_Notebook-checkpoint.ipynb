# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#import torch
#import torchvision

from bs4 import BeautifulSoup
from PIL import Image
import matplotlib.patches as patches
# provides a class with the same name which is used to represent a PIL image.
# Also provides a number of factory functions, including functions to load images from files,
# and to create new images.

# from IPython.display import display  # Public API for display tools in IPython.

# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../src/data/')
import make_dataset as md
#from src.data.make_dateset import flip_image

sys.path.insert(1, '../src/visualization/')
import visualize as vi
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-78ecb0ac419e> in <module>()
#      18 # insert at 1, 0 is the script path (or '' in REPL)
#      19 sys.path.insert(1, '../src/data/')
# ---> 20 import make_dataset as md
#      21 #from src.data.make_dateset import flip_image
#      22
#
# ~/Desktop/Projects/Mask-Detection/src/data/make_dataset.py in <module>()
#       2
#       3 import numpy as np
# ----> 4 from skimage.transform import rotate
#       5
#       6 def flip_image(image):
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/transform/__init__.py in <module>()
# ----> 1 from .hough_transform import (hough_line, hough_line_peaks,
#       2                               probabilistic_hough_line, hough_circle,
#       3                               hough_circle_peaks, hough_ellipse)
#       4 from .radon_transform import (radon, iradon, iradon_sart,
#       5                               order_angles_golden_ratio)
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/transform/hough_transform.py in <module>()
#       1 import numpy as np
#       2 from scipy import ndimage
# ----> 3 from .. import measure
#       4 from ._hough_transform import (_hough_circle,
#       5                                _hough_ellipse,
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/measure/__init__.py in <module>()
#       1 from ._find_contours import find_contours
# ----> 2 from ._marching_cubes_lewiner import marching_cubes, marching_cubes_lewiner
#       3 from ._marching_cubes_classic import (marching_cubes_classic,
#       4                                       mesh_surface_area,
#       5                                       correct_mesh_orientation)
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/measure/_marching_cubes_lewiner.py in <module>()
#      15 from . import _marching_cubes_lewiner_luts as mcluts
#      16 from . import _marching_cubes_lewiner_cy
# ---> 17 from .._shared.utils import skimage_deprecation, warn
#      18
#      19
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/_shared/utils.py in <module>()
#       8 import six
#       9
# ---> 10 from ..util import img_as_float
#      11 from ._warnings import all_warnings, warn
#      12
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/util/__init__.py in <module>()
#       5 from .apply_parallel import apply_parallel
#       6
# ----> 7 from .arraycrop import crop
#       8 from ._regular_grid import regular_grid, regular_seeds
#       9 from .unique import unique_rows
#
# ~/anaconda3/lib/python3.6/site-packages/skimage/util/arraycrop.py in <module>()
#       6
#       7 import numpy as np
# ----> 8 from numpy.lib.arraypad import _validate_lengths
#       9
#      10
#
# ImportError: cannot import name '_validate_lengths'

# %%
import skimage
print(skimage.__version__)
# Out:
# 0.13.1

# %%
img_path = '../data/raw/kaggle/images/maksssksksss0.png'
#ann_path = '../data/raw/kaggle/images/maksssksksss0.xml'
# display(Image.open(path))
image_1 = Image.open(img_path)
#Image.open(ann_path)
image_1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x366 at 0x7FB9E3CF1F98>

# %%
imgs = list(sorted(os.listdir("../data/raw/kaggle/images/")))
labels = list(sorted(os.listdir("../data/raw/kaggle/annotations/")))

# %%
labels[0]
# Out:
# '.ipynb_checkpoints'

# %%
labels[1]
# Out:
# 'maksssksksss0.xml'

# %%
image_1_flipped = md.flip_image(image_1)
image_1_rotated = md.rotate_image(image_1)
#Image.open(image_1_flipped)

# %%
vi.show_image(image_1_flipped)

# %%
vi.show_image(image_1_rotated)

# %% [markdown]
# ### Functions that will be usefull in the future but arent right now

# %% [markdown]
# #### Getting data from xml file

# %%
def gen_box(obj):
    """Getting bounding box coordinates"""
    
    xmin = int(obj.find('xmin').text)
    xmax = int(obj.find('xmax').text)
    ymin = int(obj.find('ymin').text)
    ymax = int(obj.find('ymax').text)
    
    return [xmin, ymin, xmax, ymax]

# %%
def gen_label(obj):
    """Generates labels for picture objects"""
    
    if obj.find('name').text == "with_mask":
        return "mask" #     for without_mask label set to 2
    elif obj.find('name').text == "mask_weared_incorrect":
        return "incorrect_mask"     # for mask_weared_incorrect label set to a

    return "no_mask" #     for without_mask label set to 0

# %%
# mapping for predictions and analysis purpose
options={"no_mask": 0, "incorrect_mask": 1, "mask": 2}
